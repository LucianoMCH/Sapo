# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/diplomado-bigdata-machinelearning-udea/Curso1/master/s04/adult.csv')

# %%
wc_nulos_index = df.workclass[df.workclass.isnull()].index
df.loc[wc_nulos_index,'workclass'] = df.workclass.mode().values[0]

# %%
df_filtered = df.dropna(subset=['native-country']).copy()
df_filtered.reset_index(drop=True, inplace=True)

# %%
df_filtered['occupation'].value_counts()
# Out:
# Craft-repair         6020
# Prof-specialty       6008
# Exec-managerial      5984
# Adm-clerical         5540
# Sales                5408
# Other-service        4808
# Machine-op-inspct    2970
# Transport-moving     2316
# Handlers-cleaners    2046
# Farming-fishing      1480
# Tech-support         1420
# Protective-serv       976
# Priv-house-serv       232
# Armed-Forces           14
# Name: occupation, dtype: int64

# %%
df_filtered['occupation'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df_filtered['workclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df_filtered[df_filtered['occupation'].isnull()].index
# Out:
# Int64Index([   26,    65,    73,   101,   123,   144,   149,   155,   182,
#               196,
#             ...
#             47713, 47725, 47739, 47742, 47822, 47826, 47913, 47944, 47956,
#             47981],
#            dtype='int64', length=2763)

# %%
df_nulos = df_filtered['occupation'].fillna(method='ffill')

# %%
df_filtered['occupation'].iloc[25:30]
# Out:
# 25       Craft-repair
# 26                NaN
# 27    Exec-managerial
# 28       Craft-repair
# 29    Protective-serv
# Name: occupation, dtype: object

# %%
df_nulos.iloc[25:30]
# Out:
# 25       Craft-repair
# 26       Craft-repair
# 27    Exec-managerial
# 28       Craft-repair
# 29    Protective-serv
# Name: occupation, dtype: object

# %% [markdown]
# 1. Usar fillna para remplazar los nulos en la columna **occupation** usando un método y guardando su resultado (en forma de serie) en una variable **df_nulos**
#
# 2. Usar y comparar
#
# ```
# # df_nulos.value_counts().plot(kind='bar')
# ```

# %%
df_nulosf = df_filtered['occupation'].fillna(method='ffill').copy() #reemplaza los nulos por el valor anterior
df_nulosb = df_filtered['occupation'].fillna(method='bfill').copy() #remplaza los nulos por el valor posterior

# %%
df_nulosb.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df_nulosf.value_counts().plot(kind='bar')
# Out:
# <Axes: >
